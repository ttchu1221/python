# %%
import os
path = "/Users/chuxinhui/home/python/learn_python"
print(os.listdir(path))
# Out:
# ['task.py', 'list.ipynb', 'hello_git.py', '__pycache__', 'os.ipynb', 'mutiprocess.ipynb', '.git']

# %%
def get_files(dir_path):
    '''
    列出文件夹下的所有文件
    :param dir_path: 父文件夹路径
    :return: 
    '''
    for parent, dirname, filenames in os.walk(dir_path):
        for filename in filenames:
            print("parent is:", parent)
            print("filename is:", filename)
            print("full name of the file is:", os.path.join(parent, filename))
dir = os.curdir
print("/Users/chuxinhui/home/python")
path = "/Users/chuxinhui/home/python"
get_files(path)
# Out:
# /Users/chuxinhui/home/python
# parent is: /Users/chuxinhui/home/python
# filename is: .DS_Store
# full name of the file is: /Users/chuxinhui/home/python/.DS_Store
# parent is: /Users/chuxinhui/home/python
# filename is: pso.py
# full name of the file is: /Users/chuxinhui/home/python/pso.py
# parent is: /Users/chuxinhui/home/python/leetcode
# filename is: test1.py
# full name of the file is: /Users/chuxinhui/home/python/leetcode/test1.py
# parent is: /Users/chuxinhui/home/python/leetcode
# filename is: test.py
# full name of the file is: /Users/chuxinhui/home/python/leetcode/test.py
# parent is: /Users/chuxinhui/home/python/leetcode
# filename is: test2.py
# full name of the file is: /Users/chuxinhui/home/python/leetcode/test2.py
# parent is: /Users/chuxinhui/home/python/__pycache__
# filename is: cv2.cpython-39.pyc
# full name of the file is: /Users/chuxinhui/home/python/__pycache__/cv2.cpython-39.pyc
# parent is: /Users/chuxinhui/home/python/__pycache__
# filename is: cv.cpython-39.pyc
# full name of the file is: /Users/chuxinhui/home/python/__pycache__/cv.cpython-39.pyc
# parent is: /Users/chuxinhui/home/python/learn_python
# filename is: task.py
# full name of the file is: /Users/chuxinhui/home/python/learn_python/task.py
# parent is: /Users/chuxinhui/home/python/learn_python
# filename is: list.ipynb
# full name of the file is: /Users/chuxinhui/home/python/learn_python/list.ipynb
# parent is: /Users/chuxinhui/home/python/learn_python
# filename is: hello_git.py
# full name of the file is: /Users/chuxinhui/home/python/learn_python/hello_git.py
# parent is: /Users/chuxinhui/home/python/learn_python
# filename is: os.ipynb
# full name of the file is: /Users/chuxinhui/home/python/learn_python/os.ipynb
# parent is: /Users/chuxinhui/home/python/learn_python
# filename is: mutiprocess.ipynb
# full name of the file is: /Users/chuxinhui/home/python/learn_python/mutiprocess.ipynb
# parent is: /Users/chuxinhui/home/python/learn_python/__pycache__
# filename is: task.cpython-312.pyc
# full name of the file is: /Users/chuxinhui/home/python/learn_python/__pycache__/task.cpython-312.pyc
# parent is: /Users/chuxinhui/home/python/learn_python/.git
# filename is: config
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/config
# parent is: /Users/chuxinhui/home/python/learn_python/.git
# filename is: HEAD
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/HEAD
# parent is: /Users/chuxinhui/home/python/learn_python/.git
# filename is: description
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/description
# parent is: /Users/chuxinhui/home/python/learn_python/.git
# filename is: index
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/index
# parent is: /Users/chuxinhui/home/python/learn_python/.git
# filename is: COMMIT_EDITMSG
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/COMMIT_EDITMSG
# parent is: /Users/chuxinhui/home/python/learn_python/.git/objects/f2
# filename is: d152792645fcbbcbbeeb711ecaad13eef63816
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/objects/f2/d152792645fcbbcbbeeb711ecaad13eef63816
# parent is: /Users/chuxinhui/home/python/learn_python/.git/objects/86
# filename is: 87851b467d55810f0a60dec105d424ab66b0df
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/objects/86/87851b467d55810f0a60dec105d424ab66b0df
# parent is: /Users/chuxinhui/home/python/learn_python/.git/objects/d3
# filename is: c8eb51c645da1d4b9406672ed0d43457d9f92c
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/objects/d3/c8eb51c645da1d4b9406672ed0d43457d9f92c
# parent is: /Users/chuxinhui/home/python/learn_python/.git/info
# filename is: exclude
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/info/exclude
# parent is: /Users/chuxinhui/home/python/learn_python/.git/logs
# filename is: HEAD
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/logs/HEAD
# parent is: /Users/chuxinhui/home/python/learn_python/.git/logs/refs/heads
# filename is: main
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/logs/refs/heads/main
# parent is: /Users/chuxinhui/home/python/learn_python/.git/logs/refs/remotes/origin
# filename is: main
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/logs/refs/remotes/origin/main
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: commit-msg.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/commit-msg.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: pre-rebase.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/pre-rebase.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: pre-commit.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/pre-commit.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: applypatch-msg.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/applypatch-msg.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: fsmonitor-watchman.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/fsmonitor-watchman.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: pre-receive.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/pre-receive.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: prepare-commit-msg.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/prepare-commit-msg.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: post-update.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/post-update.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: pre-merge-commit.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/pre-merge-commit.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: pre-applypatch.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/pre-applypatch.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: pre-push.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/pre-push.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: update.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/update.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/hooks
# filename is: push-to-checkout.sample
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/hooks/push-to-checkout.sample
# parent is: /Users/chuxinhui/home/python/learn_python/.git/refs/heads
# filename is: main
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/refs/heads/main
# parent is: /Users/chuxinhui/home/python/learn_python/.git/refs/remotes/origin
# filename is: main
# full name of the file is: /Users/chuxinhui/home/python/learn_python/.git/refs/remotes/origin/main
